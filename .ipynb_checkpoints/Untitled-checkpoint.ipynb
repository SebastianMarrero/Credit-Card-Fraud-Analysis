# %%
import os 
print(os.getcwd())
# Out:
# /Users/smarr/Documents/Data Sets

# %%
os.chdir('..')

# %%
os.chdir('4thProject')

# %%
print(os.getcwd())
# Out:
# /Users/smarr/Documents/Data Sets/4thProject

# %%
import pandas as pd
df=pd.read_csv("base.csv")

# %%
df.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
subset_df=df.sample(n=10000,random_state=42)

# %%
subset_df.to_csv("baseconcat.csv",index=False)
